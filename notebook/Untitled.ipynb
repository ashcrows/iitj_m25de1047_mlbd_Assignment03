# %%
pip install -r ./requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: './requirements.txt'
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

movies = pd.read_csv("dataset/ml-latest/movies.csv")
ratings = pd.read_csv("dataset/ml-latest/ratings.csv")
tags = pd.read_csv("dataset/ml-latest/tags.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       3 movies = pd.read_csv("dataset/ml-latest/movies.csv")
#       4 ratings = pd.read_csv("dataset/ml-latest/ratings.csv")
#
# ModuleNotFoundError: No module named 'pandas'
